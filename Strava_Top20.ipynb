# %%
#import library
import pandas as pd
import numpy as np
from datetime import datetime

top20 = "top20Tranposed_pace.csv"

#reading csv
top20_df = pd.read_csv(top20, encoding = 'latin-1')
top20_df
# Out:
#       Name Jorge Maravilla Ben Demaree Chris J. Matthew Duffy Nathan Krah  \
# 0    Mile1            5:44        5:43     5:46          5:47        5:46
# 1    Mile2            5:53        5:53     5:52          5:54        5:54
# 2    Mile3            5:40        5:34     5:40          5:40        5:35
# 3    Mile4            4:55        5:42     5:41          5:40        5:35
# 4    Mile5            5:42        5:36     5:44          5:43        5:40
# 5    Mile6            5:55        5:54     6:10          6:08        6:02
# 6    Mile7            5:19        5:32     5:38          5:30        5:28
# 7    Mile8            5:26        5:32     5:41          5:25        5:13
# 8    Mile9            5:34        5:41     5:57          5:42        5:35
# 9   Mile10            5:37        5:38     5:50          5:45        5:37
# 10  Mile11            5:02        5:24     5:34          5:25        5:20
# 11  Mile12            5:53        5:46     6:01          6:05        5:56
# ...

# %%
top20_df['Jorge Maravilla'] = pd.to_datetime(top20_df['Jorge Maravilla'],format= '%M:%S').dt.time
top20_df['Ben Demaree'] = pd.to_datetime(top20_df['Ben Demaree'],format= '%M:%S').dt.time
top20_df['Chris J.'] = pd.to_datetime(top20_df['Chris J.'],format= '%M:%S').dt.time
top20_df['Matthew Duffy'] = pd.to_datetime(top20_df['Matthew Duffy'],format= '%M:%S').dt.time
top20_df['Nathan Krah'] = pd.to_datetime(top20_df['Nathan Krah'],format= '%M:%S').dt.time
top20_df['Abi Agh'] = pd.to_datetime(top20_df['Abi Agh'],format= '%M:%S').dt.time
top20_df['Matt Deyo'] = pd.to_datetime(top20_df['Matt Deyo'],format= '%M:%S').dt.time
top20_df['Robert Ressl-Moyer'] = pd.to_datetime(top20_df['Robert Ressl-Moyer'],format= '%M:%S').dt.time
top20_df['Alexander Tyner'] = pd.to_datetime(top20_df['Alexander Tyner'],format= '%M:%S').dt.time
top20_df['Iain Macdonald'] = pd.to_datetime(top20_df['Iain Macdonald'],format= '%M:%S').dt.time
top20_df['Brian Solomon'] = pd.to_datetime(top20_df['Brian Solomon'],format= '%M:%S').dt.time
top20_df['Jonathan K.'] = pd.to_datetime(top20_df['Jonathan K.'],format= '%M:%S').dt.time
top20_df['Shane Young'] = pd.to_datetime(top20_df['Shane Young'],format= '%M:%S').dt.time
top20_df['Justin Mikecz'] = pd.to_datetime(top20_df['Justin Mikecz'],format= '%M:%S').dt.time
top20_df['Zac J.'] = pd.to_datetime(top20_df['Zac J.'],format= '%M:%S').dt.time
top20_df['Yu Zhang'] = pd.to_datetime(top20_df['Yu Zhang'],format= '%M:%S').dt.time
top20_df['Ian Driver'] = pd.to_datetime(top20_df['Ian Driver'],format= '%M:%S').dt.time
top20_df['Chris Schwab'] = pd.to_datetime(top20_df['Chris Schwab'],format= '%M:%S').dt.time
top20_df['Kristi C.'] = pd.to_datetime(top20_df['Kristi C.'],format= '%M:%S').dt.time
top20_df['Matthew Conrad'] = pd.to_datetime(top20_df['Matthew Conrad'],format= '%M:%S').dt.time
top20_df['Emily Sakata'] = pd.to_datetime(top20_df['Emily Sakata'],format= '%M:%S').dt.time

# %%
import matplotlib.pyplot as plt

#Plot the mile average from 1st to 10th runners.
x = range(0,27)
y1 = top20_df["Jorge Maravilla"]
y2 = top20_df['Ben Demaree']
y3 = top20_df['Chris J.']
y4 = top20_df['Matthew Duffy']
y5 = top20_df['Nathan Krah']
y6 = top20_df['Abi Agh']
y7 = top20_df['Matt Deyo']
y8 = top20_df['Robert Ressl-Moyer']
y9 = top20_df['Alexander Tyner']
y10 = top20_df['Iain Macdonald']


plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.plot(x, y5)
plt.plot(x, y6)
plt.plot(x, y7)
plt.plot(x, y8)
plt.plot(x, y9)
plt.plot(x, y10)

plt.title("Top10 runner average pace per mile")
plt.xlabel('Mile')
plt.ylabel('Average pace (min:sec / mile)')


plt.show( )

# %%
#plot the average mile pafe from 11 thruogh 20th runner
x = range(0,27)
y1 = top20_df['Brian Solomon']
y2 = top20_df['Jonathan K.']
y3 = top20_df['Shane Young']
y4 = top20_df['Justin Mikecz']
y5 = top20_df['Zac J.']
y6 = top20_df['Yu Zhang']
y7 = top20_df['Ian Driver']
y8 = top20_df['Chris Schwab']
y9 = top20_df['Kristi C.']
y10 = top20_df['Matthew Conrad']

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.plot(x, y5)
plt.plot(x, y6)
plt.plot(x, y7)
plt.plot(x, y8)
plt.plot(x, y9)
plt.plot(x, y10)

plt.title("Top 11 through 20th runer average pace per mile")
plt.xlabel('Mile')
plt.ylabel('Average pace (min:sec / mile)')

plt.show( )

# %%
#Emily's race data

y = top20_df['Emily Sakata']

plt.plot(x, y)
# no datapoint after mile 22
plt.title("Emily's average pace per mile")
plt.xlabel('Mile')
plt.ylabel('Average pace (min:sec / mile)')
plt.show( )
